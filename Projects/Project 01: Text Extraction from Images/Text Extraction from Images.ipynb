# %% [markdown]
# ![image.png](attachment:image.png)
# # <center>Text Extraction From Image </center>

# %% [markdown]
# 1. Env. Setup
# 2. Image Processing

# %%
# !pip install opencv-python
# !pip install pytesseract
# Out:
# Requirement already satisfied: opencv-python in c:\users\bytes\anaconda3\envs\ocr\lib\site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\bytes\anaconda3\envs\ocr\lib\site-packages (from opencv-python) (1.26.2)
# Requirement already satisfied: pytesseract in c:\users\bytes\anaconda3\envs\ocr\lib\site-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in c:\users\bytes\anaconda3\envs\ocr\lib\site-packages (from pytesseract) (23.1)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\bytes\anaconda3\envs\ocr\lib\site-packages (from pytesseract) (10.1.0)

# %%
import numpy as np
import cv2

image_data  =cv2.imread("./visa.jpg")
image_convert = cv2.cvtColor(image_data, cv2.COLOR_BGR2GRAY)

blurred_application = cv2.GaussianBlur(image_convert, (5, 5), 0)

_, binary_image = cv2.threshold(blurred_application, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

# %%
contours, _  = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
image_for_contour = image_data.copy()
cv2.drawContours(image_for_contour, contours, -1, (0, 255, 0), 3)
cv2.imshow("Image For Contours", image_for_contour)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

for single_contours in contours:
    x, y, w, h = cv2.boundingRect(single_contours)
    roi = image_convert[y:y+h, x:x+w]
    text = pytesseract.image_to_string(roi, config="--psm 6")
    print(text)
# Out:
# a
#
# S
#
#
# ()
#
# e
#
# —_
#
# T
#
# rT
#
# R
#
# 'e
#
#
# a
#
# x
#
# S stackoverflow i
#
# FOR TEAMS i
# Everything you —
# need to capture
# and integrate AI
# knowledge into (=)
# your workflows. , Zs

# %%
import re
clean_text  =re.sub(r'[^A-Za-z0-9]+', ' ', text)
print(clean_text)
# Out:
# x S stackoverflow i FOR TEAMS i Everything you need to capture and integrate AI knowledge into your workflows Zs
